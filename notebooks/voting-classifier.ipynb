# %% [markdown]
# Use Voting Classifiers
# ======================
#
# A [Voting classifier](http://scikit-learn.org/stable/modules/ensemble.html#voting-classifier) model combines multiple different models (i.e., sub-estimators) into a single model, which is (ideally) stronger than any of the individual models alone.
#
# [Dask](http://ml.dask.org/joblib.html) provides the software to train individual sub-estimators on different machines in a cluster. This enables users to train more models in parallel than would have been possible on a single machine. Note that users will only observe this benefit if they have a distributed cluster with more resources than their single machine (because sklearn already enables users to parallelize training across cores on a single machine).
#
# What follows is an example of how one would deploy a voting classifier model in dask (using a local cluster).
#
# <img src="http://dask.readthedocs.io/en/latest/_images/dask_horizontal.svg" width="30%" alt="Dask logo">

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import sklearn.datasets

# %% [markdown]
# We create a synthetic dataset (with 1000 rows and 20 columns) that we can give to the voting classifier model.

# %%
X, y = sklearn.datasets.make_classification(n_samples=1_000, n_features=20)

# %% [markdown]
# We specify the VotingClassifier as a list of (name, sub-estimator) tuples. Fitting the VotingClassifier on the data fits each of the sub-estimators in turn. We set the ```n_jobs``` argument to be -1, which instructs sklearn to use all available cores (notice that we haven't used dask).

# %%
classifiers = [
    ('sgd', SGDClassifier(max_iter=1000)),
    ('logisticregression', LogisticRegression()),
    ('svc', SVC(gamma='auto')),
]
clf = VotingClassifier(classifiers, n_jobs=-1)

# %% [markdown]
# We call the classifier's fit method in order to train the classifier.

# %%
# %time clf.fit(X, y)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 785 ms
# VotingClassifier(estimators=[('sgd', SGDClassifier()),
#                              ('logisticregression', LogisticRegression()),
#                              ('svc', SVC(gamma='auto'))],
#                  n_jobs=-1)

# %% [markdown]
# Creating a Dask [client](https://distributed.readthedocs.io/en/latest/client.html) provides performance and progress metrics via the dashboard. Because ```Client``` is given no arugments, its output refers to a [local cluster](http://distributed.readthedocs.io/en/latest/local-cluster.html) (not a distributed cluster).
#
# We can view the dashboard by clicking the link after running the cell.

# %%
import joblib
from distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:60867' processes=5 threads=20, memory=31.63 GiB>

# %% [markdown]
# To train the voting classifier, we call the classifier's fit method, but enclosed in joblib's ```parallel_backend``` context manager. This distributes training of sub-estimators acoss the cluster.

# %%
# %%time 
with joblib.parallel_backend("dask"):
    clf.fit(X, y)

print(clf)
# Out:
# 2024-05-27 18:58:01,145 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:60891' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'batch_of__fit_single_estimator_1_calls-3e90ca080ac24b41bf271a34a336b37a'} (stimulus_id='handle-worker-cleanup-1716850681.146247')
# 2024-05-27 18:58:01,150 - distributed.scheduler - ERROR - Couldn't gather keys: {'batch_of__fit_single_estimator_1_calls-3e90ca080ac24b41bf271a34a336b37a': 'processing'}
# 2024-05-27 18:58:01,153 - distributed.client - WARNING - Couldn't gather 1 keys, rescheduling ('batch_of__fit_single_estimator_1_calls-3e90ca080ac24b41bf271a34a336b37a',)
# 2024-05-27 18:58:01,155 - distributed.nanny - WARNING - Restarting worker
# 2024-05-27 18:58:01,321 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:60892' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'batch_of__fit_single_estimator_1_calls-d9e447fec32546c7b176cfb59c1f21dd'} (stimulus_id='handle-worker-cleanup-1716850681.3213623')
# 2024-05-27 18:58:01,322 - distributed.scheduler - ERROR - Removing worker 'tcp://127.0.0.1:60892' caused the cluster to lose scattered data, which can't be recovered: {'ndarray-37f009c3b22f47b290b4949f04161cc4', 'ndarray-ffd2205c97ce4ab485fa3baa98211498'} (stimulus_id='handle-worker-cleanup-1716850681.3213623')
# 2024-05-27 18:58:01,344 - distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\sklearn\utils\validation.py:69, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67 extra_args = len(args) - len(all_args)
#      68 if extra_args <= 0:
# ---> 69     return f(*args, **kwargs)
#      71 # extra_args > 0
#      72 args_msg = [
#      73     "{}={}".format(name, arg)
#      74     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      75 ]
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\sklearn\ensemble\_voting.py:423, in VotingClassifier.fit(self, X, y, sample_weight, **fit_params)
#     420 if sample_weight is not None:
#     421     fit_params["sample_weight"] = sample_weight
# --> 423 return super().fit(X, transformed_y, **fit_params)
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\sklearn\ensemble\_voting.py:104, in _BaseVoting.fit(self, X, y, **fit_params)
#      99         if "sample_weight" in fit_params:
#     100             routed_params[name].fit["sample_weight"] = fit_params[
#     101                 "sample_weight"
#     102             ]
# --> 104 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     105     delayed(_fit_single_estimator)(
#     106         clone(clf),
#     107         X,
#     108         y,
#     109         fit_params=routed_params[name]["fit"],
#     110         message_clsname="Voting",
#     111         message=self._log_message(name, idx + 1, len(clfs)),
#     112     )
#     113     for idx, (name, clf) in enumerate(zip(names, clfs))
#     114     if clf != "drop"
#     115 )
#     117 self.named_estimators_ = Bunch()
#     119 # Uses 'drop' as placeholder for dropped estimators
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\sklearn\utils\parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File c:\Users\copev\.pyenv\pyenv-win\versions\3.11.4\Lib\site-packages\joblib\parallel.py:1718, in Parallel._retrieve(self)
#    1716 # Flatten the batched results to output one output at a time
#    1717 batched_results = batched_results.get_result(self.timeout)
# -> 1718 for result in batched_results:
#    1719     self._nb_consumed += 1
#    1720     yield result
#
# TypeError: 'CancelledError' object is not iterable

# %% [markdown]
# Note, that we see no advantage of using dask because we are using a local cluster rather than a distributed cluster and sklearn is already using all my computer's cores. If we were using a distributed cluster, dask would enable us to take advantage of the multiple machines and train sub-estimators across them.
